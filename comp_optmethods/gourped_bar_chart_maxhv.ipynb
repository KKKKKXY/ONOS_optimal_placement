# %% [markdown]
# # Visualize the maximum of hypervolume for each algorithm

# %%
# Abvt
maxhv_Abvt_13_algo = [84700536.64419575,
84699583.53295648,
84698873.36002482,
84633155.23520696,
84485344.90368119,
83982909.13660179,
84391189.9002668,
84695027.95612651,
84630457.38459831,
84671679.72787946,
86142329.83192006,
86137966.71493277,
82515082.41032088]

# Cogent
maxhv_Cogent_13_algo = [74316643.12851894,
74018414.33150916,
71044302.49866231,
66252004.83932651,
65166255.51077402,
69440420.58666208,
74510533.89277142,
73563527.31552036,
67175407.74187371,
70696000.9345084,
69246798.32118084,
71036720.67443699,
63161919.16028393]

# Colt
maxhv_Colt_13_algo = [82258916.82437259,
82117659.41293484,
81971671.87787986,
78900221.10788774,
78531356.25096302,
79342572.08378726,
81804734.08542424,
81924579.53807221,
79412503.26779053,
80298430.72575091,
81223085.95503668,
81860943.97194515,
73808044.08022803]

# Funet
maxhv_Funet_13_algo = [84797260.5799275,
84794265.69771585,
84792573.20586881,
84715094.3221864,
84088866.16830263,
83332007.8145701,
84075711.62965536,
84779382.58802132,
84626893.24363019,
84767050.87784182,
86121243.44012459,
86113317.60999489,
82652187.72749832]

# HiberniaGlobal
maxhv_HiberniaGlobal_13_algo = [82564958.64432694,
82637974.86080505,
82551982.93672577,
82258884.95382841,
80223893.48738396,
80273827.47522144,
81777118.97209767,
82424227.31842129,
82227626.67969634,
82404628.25946435,
83686396.62256274,
83583815.42326887,
78511436.88598694]

# Intellifiber
maxhv_Intellifiber_13_algo = [83573064.96339233,
83611888.43947195,
83476496.9504721,
83178148.76183145,
79989102.25875804,
81035413.76753582,
82598559.77573383,
83294283.66598427,
83184969.04883212,
83347670.35300988,
84234093.92016193,
83993725.74015781,
78680995.50957337]

# Internode
maxhv_Internode_13_algo = [86055856.94316284,
86050848.5195399,
86047338.89614129,
85904826.26858982,
83976622.0099707,
85173154.17852993,
85816252.9176301,
86001063.1145549,
85904336.29905146,
85929657.74876645,
87642018.69232404,
87641967.79355091,
82504867.20033267]

# Ion
maxhv_Ion_13_algo = [80464272.69118793,
80143000.79677105,
80017695.7700496,
77900579.81662591,
64662387.48800223,
75893493.42855455,
79208533.21374944,
79538842.78707682,
77473362.97749442,
79333000.70670658,
79584713.24792166,
79886277.14138095,
72411329.90380196]

# Missouri
maxhv_Missouri_13_algo = [85979421.12854743,
86002356.49520646,
85995930.93797284,
85633478.687996,
83307349.03697683,
83397914.62358776,
85260670.62616202,
85842009.19011696,
85835005.53195354,
85820485.85271683,
87132555.41144818,
87196532.73383702,
81679145.74646814]

# Palmetto
maxhv_Palmetto_13_algo = [86063040.03025268,
86057889.78002636,
86067223.81389609,
85883915.70809966,
84371077.46228217,
83992977.73114409,
85438589.46218842,
85965428.3585963,
85975254.89792451,
86000154.0796664,
87401738.32618758,
87408848.30577105,
83372831.50635627]

# TataNld
maxhv_TataNld_13_algo = [77606118.06643853,
76520414.63237044,
75800859.63198814,
71528903.70146613,
63120664.32027429,
73427540.7115467,
76982090.72778562,
74650832.75816733,
72170457.02294746,
76522790.91238075,
74788642.9997225,
76289099.94446918,
68400368.54231025]

# UsCarrier
maxhv_UsCarrier_13_algo = [79799848.90946108,
79281110.83491626,
79058064.99728732,
74436882.98775479,
71925291.44018483,
74968058.08504887,
78947719.3527039,
77195359.80500436,
74523951.01967031,
78395170.99248862,
77770412.26271945,
77152046.61707047,
70863764.22626188]

# %%
# Abvt
# Cogent
# Colt
# Funet
# HiberniaGlobal
# Intellifiber
# Internode
# Ion
# Missouri
# Palmetto
# TataNld
# UsCarrier

# %% [markdown]
# ### Visualize the maximum of hypervolume for all algorithm

# %%
topos = ('Abvt', 'Cogent','Colt', 'Funet', 'HiberniaGlobal', 'Intellifiber', 'Internode', 'Ion', 'Missouri', 'Palmetto', 'TataNld', 'UsCarrier')

algos = {
    "AGEMOEA": (maxhv_Abvt_13_algo[0], maxhv_Cogent_13_algo[0], maxhv_Colt_13_algo[0],  maxhv_Funet_13_algo[0], maxhv_HiberniaGlobal_13_algo[0], maxhv_Intellifiber_13_algo[0], maxhv_Internode_13_algo[0], maxhv_Ion_13_algo[0], maxhv_Missouri_13_algo[0], maxhv_Palmetto_13_algo[0], maxhv_TataNld_13_algo[0], maxhv_UsCarrier_13_algo[0]),
    "AGEMOEA2": (maxhv_Abvt_13_algo[1], maxhv_Cogent_13_algo[1], maxhv_Colt_13_algo[1],  maxhv_Funet_13_algo[1], maxhv_HiberniaGlobal_13_algo[1], maxhv_Intellifiber_13_algo[1], maxhv_Internode_13_algo[1], maxhv_Ion_13_algo[1], maxhv_Missouri_13_algo[1], maxhv_Palmetto_13_algo[1], maxhv_TataNld_13_algo[1], maxhv_UsCarrier_13_algo[1]),
    "NSGA2": (maxhv_Abvt_13_algo[2], maxhv_Cogent_13_algo[2], maxhv_Colt_13_algo[2],  maxhv_Funet_13_algo[2], maxhv_HiberniaGlobal_13_algo[2], maxhv_Intellifiber_13_algo[2], maxhv_Internode_13_algo[2], maxhv_Ion_13_algo[2], maxhv_Missouri_13_algo[2], maxhv_Palmetto_13_algo[2], maxhv_TataNld_13_algo[2], maxhv_UsCarrier_13_algo[2]),
    "NSGA3": (maxhv_Abvt_13_algo[3], maxhv_Cogent_13_algo[3], maxhv_Colt_13_algo[3],  maxhv_Funet_13_algo[3], maxhv_HiberniaGlobal_13_algo[3], maxhv_Intellifiber_13_algo[3], maxhv_Internode_13_algo[3], maxhv_Ion_13_algo[3], maxhv_Missouri_13_algo[3], maxhv_Palmetto_13_algo[3], maxhv_TataNld_13_algo[3], maxhv_UsCarrier_13_algo[3]),
    "RNSGA2": (maxhv_Abvt_13_algo[4], maxhv_Cogent_13_algo[4], maxhv_Colt_13_algo[4],  maxhv_Funet_13_algo[4], maxhv_HiberniaGlobal_13_algo[4], maxhv_Intellifiber_13_algo[4], maxhv_Internode_13_algo[4], maxhv_Ion_13_algo[4], maxhv_Missouri_13_algo[4], maxhv_Palmetto_13_algo[4], maxhv_TataNld_13_algo[4], maxhv_UsCarrier_13_algo[4]),
    "RNSGA3": (maxhv_Abvt_13_algo[5], maxhv_Cogent_13_algo[5], maxhv_Colt_13_algo[5],  maxhv_Funet_13_algo[5], maxhv_HiberniaGlobal_13_algo[5], maxhv_Intellifiber_13_algo[5], maxhv_Internode_13_algo[5], maxhv_Ion_13_algo[5], maxhv_Missouri_13_algo[5], maxhv_Palmetto_13_algo[5], maxhv_TataNld_13_algo[5], maxhv_UsCarrier_13_algo[5]),
    "RVEA": (maxhv_Abvt_13_algo[6], maxhv_Cogent_13_algo[6], maxhv_Colt_13_algo[6],  maxhv_Funet_13_algo[6], maxhv_HiberniaGlobal_13_algo[6], maxhv_Intellifiber_13_algo[6], maxhv_Internode_13_algo[6], maxhv_Ion_13_algo[6], maxhv_Missouri_13_algo[6], maxhv_Palmetto_13_algo[6], maxhv_TataNld_13_algo[6], maxhv_UsCarrier_13_algo[6]),
    "SMSEMOA": (maxhv_Abvt_13_algo[7], maxhv_Cogent_13_algo[7], maxhv_Colt_13_algo[7],  maxhv_Funet_13_algo[7], maxhv_HiberniaGlobal_13_algo[7], maxhv_Intellifiber_13_algo[7], maxhv_Internode_13_algo[7], maxhv_Ion_13_algo[7], maxhv_Missouri_13_algo[7], maxhv_Palmetto_13_algo[7], maxhv_TataNld_13_algo[7], maxhv_UsCarrier_13_algo[7]),
    "UNSGA3": (maxhv_Abvt_13_algo[8], maxhv_Cogent_13_algo[8], maxhv_Colt_13_algo[8],  maxhv_Funet_13_algo[8], maxhv_HiberniaGlobal_13_algo[8], maxhv_Intellifiber_13_algo[8], maxhv_Internode_13_algo[8], maxhv_Ion_13_algo[8], maxhv_Missouri_13_algo[8], maxhv_Palmetto_13_algo[8], maxhv_TataNld_13_algo[8], maxhv_UsCarrier_13_algo[8]),
    "CTAEA": (maxhv_Abvt_13_algo[9], maxhv_Cogent_13_algo[9], maxhv_Colt_13_algo[9],  maxhv_Funet_13_algo[9], maxhv_HiberniaGlobal_13_algo[9], maxhv_Intellifiber_13_algo[9], maxhv_Internode_13_algo[9], maxhv_Ion_13_algo[9], maxhv_Missouri_13_algo[9], maxhv_Palmetto_13_algo[9], maxhv_TataNld_13_algo[9], maxhv_UsCarrier_13_algo[9]),
    "DNSGA2": (maxhv_Abvt_13_algo[10], maxhv_Cogent_13_algo[10], maxhv_Colt_13_algo[10],  maxhv_Funet_13_algo[10], maxhv_HiberniaGlobal_13_algo[10], maxhv_Intellifiber_13_algo[10], maxhv_Internode_13_algo[10], maxhv_Ion_13_algo[10], maxhv_Missouri_13_algo[10], maxhv_Palmetto_13_algo[10], maxhv_TataNld_13_algo[10], maxhv_UsCarrier_13_algo[10]),
    "KGBDMOEA": (maxhv_Abvt_13_algo[11], maxhv_Cogent_13_algo[11], maxhv_Colt_13_algo[11],  maxhv_Funet_13_algo[11], maxhv_HiberniaGlobal_13_algo[11], maxhv_Intellifiber_13_algo[11], maxhv_Internode_13_algo[11], maxhv_Ion_13_algo[11], maxhv_Missouri_13_algo[11], maxhv_Palmetto_13_algo[11], maxhv_TataNld_13_algo[11], maxhv_UsCarrier_13_algo[11]),
    "MOEAD": (maxhv_Abvt_13_algo[12], maxhv_Cogent_13_algo[12], maxhv_Colt_13_algo[12],  maxhv_Funet_13_algo[12], maxhv_HiberniaGlobal_13_algo[12], maxhv_Intellifiber_13_algo[12], maxhv_Internode_13_algo[12], maxhv_Ion_13_algo[12], maxhv_Missouri_13_algo[12], maxhv_Palmetto_13_algo[12], maxhv_TataNld_13_algo[12], maxhv_UsCarrier_13_algo[12])
}

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(len(topos))  # the label locations
width = 0.8/13  # the width of the bars

fig, ax = plt.subplots(figsize=(15, 8))  # Specify figsize here to make the figure larger
max_value = max(max(measurement) for measurement in algos.values())
multiplier = 0
group_padding = 1  # Adjust the padding between groups

# List of custom colors
colors = ['black', 'blue', 'red', 'orange', (0, 0, 1, 0.5), 'gray', 'purple', 'green', '#33FF57', 'brown', 'pink', 'olive', '#FF5733']

for attribute, measurement in algos.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, color=colors[multiplier])
    multiplier += 1

# Move the position of x-axis labels to the center of each group
ax.set_xticks(x + width * (len(algos) - 1) / 2)  # Adjust x-axis ticks

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Hypervolume')
ax.set_title('Comparation of maximum hypervolume for each topology')
ax.set_xticklabels(topos)
# ax.set_xticklabels(topos, rotation=45, ha='right')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.set_ylim(0, max_value + 1e6)
ax.grid(True, linestyle='--', alpha=0.7)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Visualize the maximum of hypervolume for:
# 'AGEMOEA', 'AGEMOEA2', 'NSGA2', 'NSGA3', 'RNSGA2', 'RNSGA3', 'SMSEMOA', 'UNSGA3', 'CTAEA'

# %%
topos = ('Abvt', 'Cogent','Colt', 'Funet', 'HiberniaGlobal', 'Intellifiber', 'Internode', 'Ion', 'Missouri', 'Palmetto', 'TataNld', 'UsCarrier')

algos = {
    "AGEMOEA": (maxhv_Abvt_13_algo[0], maxhv_Cogent_13_algo[0], maxhv_Colt_13_algo[0],  maxhv_Funet_13_algo[0], maxhv_HiberniaGlobal_13_algo[0], maxhv_Intellifiber_13_algo[0], maxhv_Internode_13_algo[0], maxhv_Ion_13_algo[0], maxhv_Missouri_13_algo[0], maxhv_Palmetto_13_algo[0], maxhv_TataNld_13_algo[0], maxhv_UsCarrier_13_algo[0]),
    "AGEMOEA2": (maxhv_Abvt_13_algo[1], maxhv_Cogent_13_algo[1], maxhv_Colt_13_algo[1],  maxhv_Funet_13_algo[1], maxhv_HiberniaGlobal_13_algo[1], maxhv_Intellifiber_13_algo[1], maxhv_Internode_13_algo[1], maxhv_Ion_13_algo[1], maxhv_Missouri_13_algo[1], maxhv_Palmetto_13_algo[1], maxhv_TataNld_13_algo[1], maxhv_UsCarrier_13_algo[1]),
    "NSGA2": (maxhv_Abvt_13_algo[2], maxhv_Cogent_13_algo[2], maxhv_Colt_13_algo[2],  maxhv_Funet_13_algo[2], maxhv_HiberniaGlobal_13_algo[2], maxhv_Intellifiber_13_algo[2], maxhv_Internode_13_algo[2], maxhv_Ion_13_algo[2], maxhv_Missouri_13_algo[2], maxhv_Palmetto_13_algo[2], maxhv_TataNld_13_algo[2], maxhv_UsCarrier_13_algo[2]),
    "NSGA3": (maxhv_Abvt_13_algo[3], maxhv_Cogent_13_algo[3], maxhv_Colt_13_algo[3],  maxhv_Funet_13_algo[3], maxhv_HiberniaGlobal_13_algo[3], maxhv_Intellifiber_13_algo[3], maxhv_Internode_13_algo[3], maxhv_Ion_13_algo[3], maxhv_Missouri_13_algo[3], maxhv_Palmetto_13_algo[3], maxhv_TataNld_13_algo[3], maxhv_UsCarrier_13_algo[3]),
    "RNSGA2": (maxhv_Abvt_13_algo[4], maxhv_Cogent_13_algo[4], maxhv_Colt_13_algo[4],  maxhv_Funet_13_algo[4], maxhv_HiberniaGlobal_13_algo[4], maxhv_Intellifiber_13_algo[4], maxhv_Internode_13_algo[4], maxhv_Ion_13_algo[4], maxhv_Missouri_13_algo[4], maxhv_Palmetto_13_algo[4], maxhv_TataNld_13_algo[4], maxhv_UsCarrier_13_algo[4]),
    "RNSGA3": (maxhv_Abvt_13_algo[5], maxhv_Cogent_13_algo[5], maxhv_Colt_13_algo[5],  maxhv_Funet_13_algo[5], maxhv_HiberniaGlobal_13_algo[5], maxhv_Intellifiber_13_algo[5], maxhv_Internode_13_algo[5], maxhv_Ion_13_algo[5], maxhv_Missouri_13_algo[5], maxhv_Palmetto_13_algo[5], maxhv_TataNld_13_algo[5], maxhv_UsCarrier_13_algo[5]),
    "SMSEMOA": (maxhv_Abvt_13_algo[7], maxhv_Cogent_13_algo[7], maxhv_Colt_13_algo[7],  maxhv_Funet_13_algo[7], maxhv_HiberniaGlobal_13_algo[7], maxhv_Intellifiber_13_algo[7], maxhv_Internode_13_algo[7], maxhv_Ion_13_algo[7], maxhv_Missouri_13_algo[7], maxhv_Palmetto_13_algo[7], maxhv_TataNld_13_algo[7], maxhv_UsCarrier_13_algo[7]),
    "UNSGA3": (maxhv_Abvt_13_algo[8], maxhv_Cogent_13_algo[8], maxhv_Colt_13_algo[8],  maxhv_Funet_13_algo[8], maxhv_HiberniaGlobal_13_algo[8], maxhv_Intellifiber_13_algo[8], maxhv_Internode_13_algo[8], maxhv_Ion_13_algo[8], maxhv_Missouri_13_algo[8], maxhv_Palmetto_13_algo[8], maxhv_TataNld_13_algo[8], maxhv_UsCarrier_13_algo[8]),
    "CTAEA": (maxhv_Abvt_13_algo[9], maxhv_Cogent_13_algo[9], maxhv_Colt_13_algo[9],  maxhv_Funet_13_algo[9], maxhv_HiberniaGlobal_13_algo[9], maxhv_Intellifiber_13_algo[9], maxhv_Internode_13_algo[9], maxhv_Ion_13_algo[9], maxhv_Missouri_13_algo[9], maxhv_Palmetto_13_algo[9], maxhv_TataNld_13_algo[9], maxhv_UsCarrier_13_algo[9]),
}

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(len(topos))  # the label locations
width = 1/13  # the width of the bars

fig, ax = plt.subplots(figsize=(15, 8))  # Specify figsize here to make the figure larger
max_value = max(max(measurement) for measurement in algos.values())
multiplier = 0
group_padding = 1  # Adjust the padding between groups

# List of custom colors
colors = ['black', 'blue', 'red', 'orange', (0, 0, 1, 0.5), 'gray', 'green', '#33FF57', 'brown']

for attribute, measurement in algos.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, color=colors[multiplier])
    multiplier += 1

# Move the position of x-axis labels to the center of each group
ax.set_xticks(x + width * (len(algos) - 1) / 2)  # Adjust x-axis ticks

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Hypervolume')
ax.set_title('Comparation of maximum hypervolume for each topology')
ax.set_xticklabels(topos)
# ax.set_xticklabels(topos, rotation=45, ha='right')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.set_ylim(0, max_value + 1e6)
ax.grid(True, linestyle='--', alpha=0.7)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

plt.show()
