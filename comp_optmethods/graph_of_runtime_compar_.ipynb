# %% [markdown]
# ## Store run time for 9 algorithms

# %%
# rt_of_Cogent = [22724.22938632970000, 22453.41155004500000, 21603.76220011710000, 22636.78463387490000, 21062.22639894490000, 22466.13221693040000, 32882.88317489620000, 22534.99886870380000, 22456.82143306730000, 25221.18716025350000, 21279.31321358680000, 21256.28330254550000, 17446.09957480430000]
# method_label = ['AGEMOEA', 'AGEMOEA2', 'NSGA2', 'NSGA3', 'RNSGA2', 'RNSGA3', 'RVEA', 'SMSEMOA', 'UNSGA3', 'CTAEA', 'DNSGA2', 'KGBDMOEA', 'MOEAD']

rt_of_Cogent = [22724.22938632970000, 22453.41155004500000, 21603.76220011710000, 22636.78463387490000, 21062.22639894490000, 22466.13221693040000, 32882.88317489620000, 22534.99886870380000, 22456.82143306730000]
rt_of_UsCarrier = [15646.81463217740000, 16497.77872705460000, 16020.12257409100000, 16675.38979220390000, 15687.98048710820000, 16467.79012632370000, 23351.09611153600000, 17038.53184556960000, 16553.08904194830000]
rt_of_HiberniaGlobal = [2009.07824015617000, 2034.16026878357000, 1992.14481997490000, 1992.75803709030000, 1991.95467829704000, 1983.48965215683000, 3153.54659175873000, 2100.28386712074000, 1992.92309021950000]
rt_of_Colt = [12424.65377116200000, 12685.91720366480000, 12205.51165390010000, 12575.69846558570000, 12073.19257187840000, 12683.39596390720000, 19040.42915821080000, 12519.64864540100000, 12424.86489105220000]
rt_of_Funet = [681.29192185401900, 691.57882785797100, 659.77488613128700, 664.56862807273900, 671.28866529464700, 663.53386735916100, 1047.80687403679000, 752.02748131752000, 660.67869019508400]
rt_of_Abvt = [601.33047223091100, 607.77908897399900, 581.04515147209200, 584.73350930213900, 583.74846863746600, 372.15372252464300, 927.42029953002900, 632.86163210868800, 585.90173697471600]
rt_of_Intellifiber = [3089.69057655334000, 3107.24349379540000, 3036.87341094017000, 3050.16903972626000, 3032.39215922356000, 2996.73027777672000, 4788.27870535851000, 3164.55398488045000, 3002.48968887329000]
rt_of_TataNld = [11884.97514367100000, 12188.14339470860000, 11787.08821940420000, 12130.55840921400000, 11624.68266296390000, 12139.67185664180000, 18420.39831662180000, 12412.63009262090000, 12274.42391586300000]
# rt_of_Kdl = []
rt_of_Internode = [2225.63560962677000, 2246.06417441368000, 2176.77353405952000, 2183.55182695389000, 2157.83526825905000, 2174.93785524368000, 3547.84674811363000, 2286.23174405098000, 2157.25861263275000]
rt_of_Missouri = [2624.18822717667000, 2652.40523409843000, 2591.95758485794000, 2607.25942492485000, 2515.11694574356000, 2558.21776533127000, 4167.13097071648000, 2773.90830898285000, 2591.80622863770000]
rt_of_Ion = [9132.46448349953000, 9404.81001901627000, 9136.43432664871000, 9497.30357575417000, 9084.26194787026000, 9179.20096445084000, 13859.05025649070000, 9841.28463006020000, 9354.74517083168000]
rt_of_Palmetto = [1430.56280112267000, 1440.17222046852000, 1406.13915896416000, 1417.98838186264000, 1393.31535172462000, 1403.26148247719000, 2270.44990253449000, 1497.41798114777000, 1417.04476428032000]
method_label = ['AGEMOEA', 'AGEMOEA2', 'NSGA2', 'NSGA3', 'RNSGA2', 'RNSGA3', 'RVEA', 'SMSEMOA', 'UNSGA3']

# %% [markdown]
# ## Draw Figure (9 algorithms)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define and plot the x-axis (method name) and y-axis (running time)
plt.figure(figsize=(10, 5))
plt.plot(method_label, rt_of_Cogent,  color='black', label='Cogent(197)')
plt.plot(method_label, rt_of_UsCarrier,  color='blue', label='UsCarrier(158)')
plt.plot(method_label, rt_of_HiberniaGlobal,  color='orange', label='HiberniaGlobal(55)')
plt.plot(method_label, rt_of_Colt,  color='green', label='Colt(153)')
plt.plot(method_label, rt_of_Funet,  color='red', label='Funet(26)')
plt.plot(method_label, rt_of_Abvt,  color='purple', label='Abvt(23)')
plt.plot(method_label, rt_of_Intellifiber,  color='brown', label='Intellifiber(73)')
plt.plot(method_label, rt_of_TataNld,  color='pink', label='TataNld(145)')
# plt.plot(method_label, rt_of_Kdl,  color='#5733FF', label='Kdl(754)')
plt.plot(method_label, rt_of_Internode,  color='olive', label='Internode(66)')
plt.plot(method_label, rt_of_Missouri,  color='cyan', label='Missouri(67)')
plt.plot(method_label, rt_of_Ion,  color='#FF5733', label='Ion(125)')
plt.plot(method_label, rt_of_Palmetto,  color='#33FF57', label='Palmetto(45)')

# Find the lowest running time for each topology
min_Cogent, i_Cogent = np.min(rt_of_Cogent), np.argmin(rt_of_Cogent)
min_UsCarrier, i_UsCarrier = np.min(rt_of_UsCarrier), np.argmin(rt_of_UsCarrier)
min_HiberniaGlobal, i_HiberniaGlobal = np.min(rt_of_HiberniaGlobal), np.argmin(rt_of_HiberniaGlobal)
min_Colt, i_Colt = np.min(rt_of_Colt), np.argmin(rt_of_Colt)
min_Funet, i_Funet = np.min(rt_of_Funet), np.argmin(rt_of_Funet)
min_Abvt, i_Abvt = np.min(rt_of_Abvt), np.argmin(rt_of_Abvt)
min_Intellifiber, i_Intellifiber = np.min(rt_of_Intellifiber), np.argmin(rt_of_Intellifiber)
min_TataNld, i_TataNld = np.min(rt_of_TataNld), np.argmin(rt_of_TataNld)
# min_Kdl, i_Kdl = np.min(rt_of_Kdl), np.argmin(rt_of_Kdl)
min_Internode, i_Internode = np.min(rt_of_Internode), np.argmin(rt_of_Internode)
min_Missouri, i_Missouri = np.min(rt_of_Missouri), np.argmin(rt_of_Missouri)
min_Ion, i_Ion = np.min(rt_of_Ion), np.argmin(rt_of_Ion)
min_Palmetto, i_Palmetto = np.min(rt_of_Palmetto), np.argmin(rt_of_Palmetto)

# scatter the lowest point
plt.scatter(i_Cogent, min_Cogent, color='black', marker="*", s=150)
plt.scatter(i_UsCarrier, min_UsCarrier, color='blue', marker="*", s=150)
plt.scatter(i_HiberniaGlobal, min_HiberniaGlobal, color='orange', marker="*", s=150)
plt.scatter(i_Colt, min_Colt, color='green', marker="*", s=150)
plt.scatter(i_Funet, min_Funet, color='red', marker="*", s=150)
plt.scatter(i_Abvt, min_Abvt, color='purple', marker="*", s=150)
plt.scatter(i_Intellifiber, min_Intellifiber, color='brown', marker="*", s=150)
plt.scatter(i_TataNld, min_TataNld, color='pink', marker="*", s=150)
# plt.scatter(i_Kdl, min_Kdl, color='#5733FF', marker="*", s=150)
plt.scatter(i_Internode, min_Internode, color='olive', marker="*", s=150)
plt.scatter(i_Missouri, min_Missouri, color='cyan', marker="*", s=150)
plt.scatter(i_Ion, min_Ion, color='#FF5733', marker="*", s=150)
plt.scatter(i_Palmetto, min_Palmetto, color='#33FF57', marker="*", s=150)

plt.title("Comparation of run time for each method")
plt.xlabel("Name of Methods")
plt.ylabel("Run Time (sec)")
plt.legend()
plt.show()

# %% [markdown]
# ## Store run time for all algorithms

# %%
# rt_of_Cogent = [22724.22938632970000, 22453.41155004500000, 21603.76220011710000, 22636.78463387490000, 21062.22639894490000, 22466.13221693040000, 32882.88317489620000, 22534.99886870380000, 22456.82143306730000, 25221.18716025350000, 21279.31321358680000, 21256.28330254550000, 17446.09957480430000]


rt_of_Cogent = [22724.22938632970000, 22453.41155004500000, 21603.76220011710000, 22636.78463387490000, 21062.22639894490000, 22466.13221693040000, 32882.88317489620000, 22534.99886870380000, 22456.82143306730000, 25221.18716025350000, 21279.3132135868000, 21256.28330254550000, 17446.09957480430000]
rt_of_UsCarrier = [15646.81463217740000, 16497.77872705460000, 16020.12257409100000, 16675.38979220390000, 15687.98048710820000, 16467.79012632370000, 23351.09611153600000, 17038.53184556960000, 16553.08904194830000, 16107.26577234270000, 16083.32063531880000, 16132.82397198680000, 15595.45906233790000]
rt_of_HiberniaGlobal = [2009.07824015617000, 2034.16026878357000, 1992.14481997490000, 1992.75803709030000, 1991.95467829704000, 1983.48965215683000, 3153.54659175873000, 2100.28386712074000, 1992.92309021950000, 650.64476084709200, 555.40303134918200, 747.62700152397200, 869.40291881561300]
rt_of_Colt = [12424.65377116200000, 12685.91720366480000, 12205.51165390010000, 12575.69846558570000, 12073.19257187840000, 12683.39596390720000, 19040.42915821080000, 12519.64864540100000, 12424.86489105220000, 12695.30470395090000, 10616.64863562580000, 9453.05619263649000, 9870.84597420692000]
rt_of_Funet = [681.29192185401900, 691.57882785797100, 659.77488613128700, 664.56862807273900, 671.28866529464700, 663.53386735916100, 1047.80687403679000, 752.02748131752000, 660.67869019508400, 109.35145926475500, 169.61638569831800, 149.27592682838400, 362.91382551193200]
rt_of_Abvt = [601.33047223091100, 607.77908897399900, 581.04515147209200, 584.73350930213900, 583.74846863746600, 372.15372252464300, 927.42029953002900, 632.86163210868800, 585.90173697471600, 124.82140159606900, 111.78843879699700, 108.30169510841400, 179.58662056922900]
rt_of_Intellifiber = [3089.69057655334000, 3107.24349379540000, 3036.87341094017000, 3050.16903972626000, 3032.39215922356000, 2996.73027777672000, 4788.27870535851000, 3164.55398488045000, 3002.48968887329000, 1230.53672885895000, 1281.18206405640000, 1246.67425274849000, 2961.80341649056000]
rt_of_TataNld = [11884.97514367100000, 12188.14339470860000, 11787.08821940420000, 12130.55840921400000, 11624.68266296390000, 12139.67185664180000, 18420.39831662180000, 12412.63009262090000, 12274.42391586300000, 11411.82412028310000, 11251.96977376940000, 12046.36181879040000, 11800.15689682960000]
# rt_of_Kdl = []
rt_of_Internode = [2225.63560962677000, 2246.06417441368000, 2176.77353405952000, 2183.55182695389000, 2157.83526825905000, 2174.93785524368000, 3547.84674811363000, 2286.23174405098000, 2157.25861263275000, 738.25645208358800, 598.95412254333500, 808.64122557640100, 1521.82503986359000]
rt_of_Missouri = [2624.18822717667000, 2652.40523409843000, 2591.95758485794000, 2607.25942492485000, 2515.11694574356000, 2558.21776533127000, 4167.13097071648000, 2773.90830898285000, 2591.80622863770000, 1015.37011814117000, 1246.14025425911000, 1246.17837548256000, 1166.82210874558000]
rt_of_Ion = [9132.46448349953000, 9404.81001901627000, 9136.43432664871000, 9497.30357575417000, 9084.26194787026000, 9179.20096445084000, 13859.05025649070000, 9841.28463006020000, 9354.74517083168000, 10416.49086093900000, 7429.36154484749000, 8009.16168594360000, 6179.63929319382000]
rt_of_Palmetto = [1430.56280112267000, 1440.17222046852000, 1406.13915896416000, 1417.98838186264000, 1393.31535172462000, 1403.26148247719000, 2270.44990253449000, 1497.41798114777000, 1417.04476428032000, 382.14858841896100, 421.10140562057500, 427.96273851394700, 701.98675990104700]
method_label = ['AGEMOEA', 'AGEMOEA2', 'NSGA2', 'NSGA3', 'RNSGA2', 'RNSGA3', 'RVEA', 'SMSEMOA', 'UNSGA3', 'CTAEA', 'DNSGA2', 'KGBDMOEA', 'MOEAD']

# %% [markdown]
# ## Draw Figure (all algorithms)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define and plot the x-axis (method name) and y-axis (running time)
plt.figure(figsize=(15, 5))
plt.plot(method_label, rt_of_Cogent,  color='black', label='Cogent(197)')
plt.plot(method_label, rt_of_UsCarrier,  color='blue', label='UsCarrier(158)')
plt.plot(method_label, rt_of_HiberniaGlobal,  color='orange', label='HiberniaGlobal(55)')
plt.plot(method_label, rt_of_Colt,  color='green', label='Colt(153)')
plt.plot(method_label, rt_of_Funet,  color='red', label='Funet(26)')
plt.plot(method_label, rt_of_Abvt,  color='purple', label='Abvt(23)')
plt.plot(method_label, rt_of_Intellifiber,  color='brown', label='Intellifiber(73)')
plt.plot(method_label, rt_of_TataNld,  color='pink', label='TataNld(145)')
# plt.plot(method_label, rt_of_Kdl,  color='#5733FF', label='Kdl(754)')
plt.plot(method_label, rt_of_Internode,  color='olive', label='Internode(66)')
plt.plot(method_label, rt_of_Missouri,  color='cyan', label='Missouri(67)')
plt.plot(method_label, rt_of_Ion,  color='#FF5733', label='Ion(125)')
plt.plot(method_label, rt_of_Palmetto,  color='#33FF57', label='Palmetto(45)')

# Find the lowest running time for each topology
min_Cogent, i_Cogent = np.min(rt_of_Cogent), np.argmin(rt_of_Cogent)
min_UsCarrier, i_UsCarrier = np.min(rt_of_UsCarrier), np.argmin(rt_of_UsCarrier)
min_HiberniaGlobal, i_HiberniaGlobal = np.min(rt_of_HiberniaGlobal), np.argmin(rt_of_HiberniaGlobal)
min_Colt, i_Colt = np.min(rt_of_Colt), np.argmin(rt_of_Colt)
min_Funet, i_Funet = np.min(rt_of_Funet), np.argmin(rt_of_Funet)
min_Abvt, i_Abvt = np.min(rt_of_Abvt), np.argmin(rt_of_Abvt)
min_Intellifiber, i_Intellifiber = np.min(rt_of_Intellifiber), np.argmin(rt_of_Intellifiber)
min_TataNld, i_TataNld = np.min(rt_of_TataNld), np.argmin(rt_of_TataNld)
# min_Kdl, i_Kdl = np.min(rt_of_Kdl), np.argmin(rt_of_Kdl)
min_Internode, i_Internode = np.min(rt_of_Internode), np.argmin(rt_of_Internode)
min_Missouri, i_Missouri = np.min(rt_of_Missouri), np.argmin(rt_of_Missouri)
min_Ion, i_Ion = np.min(rt_of_Ion), np.argmin(rt_of_Ion)
min_Palmetto, i_Palmetto = np.min(rt_of_Palmetto), np.argmin(rt_of_Palmetto)

# scatter the lowest point
plt.scatter(i_Cogent, min_Cogent, color='black', marker="*", s=150)
plt.scatter(i_UsCarrier, min_UsCarrier, color='blue', marker="*", s=150)
plt.scatter(i_HiberniaGlobal, min_HiberniaGlobal, color='orange', marker="*", s=150)
plt.scatter(i_Colt, min_Colt, color='green', marker="*", s=150)
plt.scatter(i_Funet, min_Funet, color='red', marker="*", s=150)
plt.scatter(i_Abvt, min_Abvt, color='purple', marker="*", s=150)
plt.scatter(i_Intellifiber, min_Intellifiber, color='brown', marker="*", s=150)
plt.scatter(i_TataNld, min_TataNld, color='pink', marker="*", s=150)
# plt.scatter(i_Kdl, min_Kdl, color='#5733FF', marker="*", s=150)
plt.scatter(i_Internode, min_Internode, color='olive', marker="*", s=150)
plt.scatter(i_Missouri, min_Missouri, color='cyan', marker="*", s=150)
plt.scatter(i_Ion, min_Ion, color='#FF5733', marker="*", s=150)
plt.scatter(i_Palmetto, min_Palmetto, color='#33FF57', marker="*", s=150)

plt.title("Comparation of run time for each method")
plt.xlabel("Name of Methods")
plt.ylabel("Run Time (sec)")
plt.legend(loc='center left')
plt.show()
