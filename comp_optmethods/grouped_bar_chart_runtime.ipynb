4579.9874019622800000,
4595.1032090187000000,
1878.3313298225400000,]
rt_of_Missouri = [2591.8274204730900000,
2662.2753105163500000,
2590.5200242996200000,
2470.7606685161500000,
2461.0775036811800000,
2256.9365243911700000,
2521.9392526149700000,
2750.6826860904600000,
2606.3202712535800000,
2141.2858262062000000,
5234.9582068920100000,
5501.6668252944900000,
2220.8871889114300000,]
rt_of_Ion = [9022.1977381706200000,
9170.6009433269500000,
8933.5709657669000000,
9278.1511740684500000,
8735.7986574172900000,
7711.1090118885000000,
8372.7654759883800000,
9860.2943344116200000,
9322.3435323238300000,
7615.6680052280400000,
19337.5272212028000000,
19551.2564609050000000,
7640.2844974994600000,]
rt_of_Palmetto = [1434.1422026157300000,
1447.9512310028000000,
1404.8261182308100000,
1421.3100476264900000,
1398.9325253963400000,
1236.6183550357800000,
1381.9259831905300000,
1502.2042768001500000,
1353.4550714492700000,
1218.2558038234700000,
2953.3097920417700000,
2795.7615985870300000,
1217.7234907150200000,]
# from scipy.stats import rankdata

# # Create a dictionary mapping algorithm names to their average values
# all_aver = {
#     "AGEMOEA": aver_AGEMOEA,
#     "AGEMOEA2": aver_AGEMOEA2,
#     "NSGA2": aver_NSGA2,
#     "NSGA3": aver_NSGA3,
#     "RNSGA2": aver_RNSGA2,
#     "RNSGA3": aver_RNSGA3,
#     "RVEA": aver_RVEA,
#     "SMSEMOA": aver_SMSEMOA,
#     "UNSGA3": aver_UNSGA3,
#     "CTAEA": aver_CTAEA,
#     "DNSGA2": aver_DNSGA2,
#     "KGBDMOEA": aver_KGBDMOEA,
#     "MOEAD": aver_MOEAD
# }

# # Rank the average values
# ranked_all = rankdata(list(all_aver.values()))

# # Sort the algorithm names based on the ranks
# sorted_all_with_rank = sorted(zip(ranked_all, all_aver.keys()))

# # Print the ranked algorithms
# print("Ranked data:", sorted_all_with_rank)

# # method_label = ['AGEMOEA', 'AGEMOEA2', 'NSGA2', 'NSGA3', 'RNSGA2', 'RNSGA3', 'RVEA', 'SMSEMOA', 'UNSGA3', 'CTAEA', 'DNSGA2', 'KGBDMOEA', 'MOEAD']
# rt_of_Abvt, rt_of_Cogent, rt_of_HiberniaGlobal, rt_of_Colt, rt_of_Funet, rt_of_UsCarrier, rt_of_Intellifiber, rt_of_TataNld, rt_of_Internode, rt_of_Missouri, rt_of_Ion, rt_of_Palmetto = zip(rt_of_AGEMOEA, rt_of_AGEMOEA2, rt_of_NSGA2, rt_of_NSGA3, rt_of_RNSGA2, rt_of_RNSGA3, rt_of_RVEA, rt_of_SMSEMOA, rt_of_UNSGA3, rt_of_CTAEA, rt_of_DNSGA2, rt_of_KGBDMOEA, rt_of_MOEAD)

# %% [markdown]
# ### Visualize the maximum of hypervolume for all algorithm

# %%
topos = ('Abvt', 'Cogent','Colt', 'Funet', 'HiberniaGlobal', 'Intellifiber', 'Internode', 'Ion', 'Missouri', 'Palmetto', 'TataNld', 'UsCarrier')

algos = {
    "AGEMOEA": (rt_of_Abvt[0], rt_of_Cogent[0], rt_of_Colt[0],  rt_of_Funet[0], rt_of_HiberniaGlobal[0], rt_of_Intellifiber[0], rt_of_Internode[0], rt_of_Ion[0], rt_of_Missouri[0], rt_of_Palmetto[0], rt_of_TataNld[0], rt_of_UsCarrier[0]),
    "AGEMOEA2": (rt_of_Abvt[1], rt_of_Cogent[1], rt_of_Colt[1],  rt_of_Funet[1], rt_of_HiberniaGlobal[1], rt_of_Intellifiber[1], rt_of_Internode[1], rt_of_Ion[1], rt_of_Missouri[1], rt_of_Palmetto[1], rt_of_TataNld[1], rt_of_UsCarrier[1]),
    "NSGA2": (rt_of_Abvt[2], rt_of_Cogent[2], rt_of_Colt[2],  rt_of_Funet[2], rt_of_HiberniaGlobal[2], rt_of_Intellifiber[2], rt_of_Internode[2], rt_of_Ion[2], rt_of_Missouri[2], rt_of_Palmetto[2], rt_of_TataNld[2], rt_of_UsCarrier[2]),
    "NSGA3": (rt_of_Abvt[3], rt_of_Cogent[3], rt_of_Colt[3],  rt_of_Funet[3], rt_of_HiberniaGlobal[3], rt_of_Intellifiber[3], rt_of_Internode[3], rt_of_Ion[3], rt_of_Missouri[3], rt_of_Palmetto[3], rt_of_TataNld[3], rt_of_UsCarrier[3]),
    "RNSGA2": (rt_of_Abvt[4], rt_of_Cogent[4], rt_of_Colt[4],  rt_of_Funet[4], rt_of_HiberniaGlobal[4], rt_of_Intellifiber[4], rt_of_Internode[4], rt_of_Ion[4], rt_of_Missouri[4], rt_of_Palmetto[4], rt_of_TataNld[4], rt_of_UsCarrier[4]),
    "RNSGA3": (rt_of_Abvt[5], rt_of_Cogent[5], rt_of_Colt[5],  rt_of_Funet[5], rt_of_HiberniaGlobal[5], rt_of_Intellifiber[5], rt_of_Internode[5], rt_of_Ion[5], rt_of_Missouri[5], rt_of_Palmetto[5], rt_of_TataNld[5], rt_of_UsCarrier[5]),
    "RVEA": (rt_of_Abvt[6], rt_of_Cogent[6], rt_of_Colt[6],  rt_of_Funet[6], rt_of_HiberniaGlobal[6], rt_of_Intellifiber[6], rt_of_Internode[6], rt_of_Ion[6], rt_of_Missouri[6], rt_of_Palmetto[6], rt_of_TataNld[6], rt_of_UsCarrier[6]),
    "SMSEMOA": (rt_of_Abvt[7], rt_of_Cogent[7], rt_of_Colt[7],  rt_of_Funet[7], rt_of_HiberniaGlobal[7], rt_of_Intellifiber[7], rt_of_Internode[7], rt_of_Ion[7], rt_of_Missouri[7], rt_of_Palmetto[7], rt_of_TataNld[7], rt_of_UsCarrier[7]),
    "UNSGA3": (rt_of_Abvt[8], rt_of_Cogent[8], rt_of_Colt[8],  rt_of_Funet[8], rt_of_HiberniaGlobal[8], rt_of_Intellifiber[8], rt_of_Internode[8], rt_of_Ion[8], rt_of_Missouri[8], rt_of_Palmetto[8], rt_of_TataNld[8], rt_of_UsCarrier[8]),
    "CTAEA": (rt_of_Abvt[9], rt_of_Cogent[9], rt_of_Colt[9],  rt_of_Funet[9], rt_of_HiberniaGlobal[9], rt_of_Intellifiber[9], rt_of_Internode[9], rt_of_Ion[9], rt_of_Missouri[9], rt_of_Palmetto[9], rt_of_TataNld[9], rt_of_UsCarrier[9]),
    "DNSGA2": (rt_of_Abvt[10], rt_of_Cogent[10], rt_of_Colt[10],  rt_of_Funet[10], rt_of_HiberniaGlobal[10], rt_of_Intellifiber[10], rt_of_Internode[10], rt_of_Ion[10], rt_of_Missouri[10], rt_of_Palmetto[10], rt_of_TataNld[10], rt_of_UsCarrier[10]),
    "KGBDMOEA": (rt_of_Abvt[11], rt_of_Cogent[11], rt_of_Colt[11],  rt_of_Funet[11], rt_of_HiberniaGlobal[11], rt_of_Intellifiber[11], rt_of_Internode[11], rt_of_Ion[11], rt_of_Missouri[11], rt_of_Palmetto[11], rt_of_TataNld[11], rt_of_UsCarrier[11]),
    "MOEAD": (rt_of_Abvt[12], rt_of_Cogent[12], rt_of_Colt[12],  rt_of_Funet[12], rt_of_HiberniaGlobal[12], rt_of_Intellifiber[12], rt_of_Internode[12], rt_of_Ion[12], rt_of_Missouri[12], rt_of_Palmetto[12], rt_of_TataNld[12], rt_of_UsCarrier[12])
}

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(len(topos))  # the label locations
width = 0.8/13  # the width of the bars

fig, ax = plt.subplots(figsize=(15, 8))  # Specify figsize here to make the figure larger
max_value = max(max(measurement) for measurement in algos.values())
multiplier = 0
group_padding = 1  # Adjust the padding between groups

# List of custom colors
colors = ['black', 'blue', 'red', 'orange', (0, 0, 1, 0.5), 'gray', 'purple', 'green', '#33FF57', 'brown', 'pink', 'olive', '#FF5733']

for attribute, measurement in algos.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, color=colors[multiplier])
    multiplier += 1

# Move the position of x-axis labels to the center of each group
ax.set_xticks(x + width * (len(algos) - 1) / 2)  # Adjust x-axis ticks

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Hypervolume')
ax.set_title('Comparation of maximum hypervolume for each topology')
ax.set_xticklabels(topos)
# ax.set_xticklabels(topos, rotation=45, ha='right')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.set_ylim(0, max_value + 1000)
ax.grid(True, linestyle='--', alpha=0.7)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Visualize the maximum of hypervolume for:
# 'AGEMOEA', 'AGEMOEA2', 'NSGA2', 'NSGA3', 'RNSGA2', 'RNSGA3', 'SMSEMOA', 'UNSGA3', 'CTAEA'

# %%
topos = ('Abvt', 'Cogent','Colt', 'Funet', 'HiberniaGlobal', 'Intellifiber', 'Internode', 'Ion', 'Missouri', 'Palmetto', 'TataNld', 'UsCarrier')

algos = {
    "AGEMOEA": (rt_of_Abvt[0], rt_of_Cogent[0], rt_of_Colt[0],  rt_of_Funet[0], rt_of_HiberniaGlobal[0], rt_of_Intellifiber[0], rt_of_Internode[0], rt_of_Ion[0], rt_of_Missouri[0], rt_of_Palmetto[0], rt_of_TataNld[0], rt_of_UsCarrier[0]),
    "AGEMOEA2": (rt_of_Abvt[1], rt_of_Cogent[1], rt_of_Colt[1],  rt_of_Funet[1], rt_of_HiberniaGlobal[1], rt_of_Intellifiber[1], rt_of_Internode[1], rt_of_Ion[1], rt_of_Missouri[1], rt_of_Palmetto[1], rt_of_TataNld[1], rt_of_UsCarrier[1]),
    "NSGA2": (rt_of_Abvt[2], rt_of_Cogent[2], rt_of_Colt[2],  rt_of_Funet[2], rt_of_HiberniaGlobal[2], rt_of_Intellifiber[2], rt_of_Internode[2], rt_of_Ion[2], rt_of_Missouri[2], rt_of_Palmetto[2], rt_of_TataNld[2], rt_of_UsCarrier[2]),
    "NSGA3": (rt_of_Abvt[3], rt_of_Cogent[3], rt_of_Colt[3],  rt_of_Funet[3], rt_of_HiberniaGlobal[3], rt_of_Intellifiber[3], rt_of_Internode[3], rt_of_Ion[3], rt_of_Missouri[3], rt_of_Palmetto[3], rt_of_TataNld[3], rt_of_UsCarrier[3]),
    "RNSGA2": (rt_of_Abvt[4], rt_of_Cogent[4], rt_of_Colt[4],  rt_of_Funet[4], rt_of_HiberniaGlobal[4], rt_of_Intellifiber[4], rt_of_Internode[4], rt_of_Ion[4], rt_of_Missouri[4], rt_of_Palmetto[4], rt_of_TataNld[4], rt_of_UsCarrier[4]),
    "RNSGA3": (rt_of_Abvt[5], rt_of_Cogent[5], rt_of_Colt[5],  rt_of_Funet[5], rt_of_HiberniaGlobal[5], rt_of_Intellifiber[5], rt_of_Internode[5], rt_of_Ion[5], rt_of_Missouri[5], rt_of_Palmetto[5], rt_of_TataNld[5], rt_of_UsCarrier[5]),
    "SMSEMOA": (rt_of_Abvt[7], rt_of_Cogent[7], rt_of_Colt[7],  rt_of_Funet[7], rt_of_HiberniaGlobal[7], rt_of_Intellifiber[7], rt_of_Internode[7], rt_of_Ion[7], rt_of_Missouri[7], rt_of_Palmetto[7], rt_of_TataNld[7], rt_of_UsCarrier[7]),
    "UNSGA3": (rt_of_Abvt[8], rt_of_Cogent[8], rt_of_Colt[8],  rt_of_Funet[8], rt_of_HiberniaGlobal[8], rt_of_Intellifiber[8], rt_of_Internode[8], rt_of_Ion[8], rt_of_Missouri[8], rt_of_Palmetto[8], rt_of_TataNld[8], rt_of_UsCarrier[8]),
    "CTAEA": (rt_of_Abvt[9], rt_of_Cogent[9], rt_of_Colt[9],  rt_of_Funet[9], rt_of_HiberniaGlobal[9], rt_of_Intellifiber[9], rt_of_Internode[9], rt_of_Ion[9], rt_of_Missouri[9], rt_of_Palmetto[9], rt_of_TataNld[9], rt_of_UsCarrier[9]),
}

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(len(topos))  # the label locations
width = 1/13  # the width of the bars

fig, ax = plt.subplots(figsize=(15, 8))  # Specify figsize here to make the figure larger
max_value = max(max(measurement) for measurement in algos.values())
multiplier = 0
group_padding = 1  # Adjust the padding between groups

# List of custom colors
colors = ['black', 'blue', 'red', 'orange', (0, 0, 1, 0.5), 'gray', 'green', '#33FF57', 'brown']

for attribute, measurement in algos.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute, color=colors[multiplier])
    multiplier += 1

# Move the position of x-axis labels to the center of each group
ax.set_xticks(x + width * (len(algos) - 1) / 2)  # Adjust x-axis ticks

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Hypervolume')
ax.set_title('Comparation of maximum hypervolume for each topology')
ax.set_xticklabels(topos)
# ax.set_xticklabels(topos, rotation=45, ha='right')
ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.set_ylim(0, max_value + 1000)
ax.grid(True, linestyle='--', alpha=0.7)

# Adjust layout to prevent clipping of labels
plt.tight_layout()

plt.show()
