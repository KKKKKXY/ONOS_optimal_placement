

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define and plot the x-axis (method name) and y-axis (running time)
plt.figure(figsize=(10, 5))
plt.plot(method_label, rt_of_Cogent,  color='black', label='Cogent(197)')
plt.plot(method_label, rt_of_UsCarrier,  color='blue', label='UsCarrier(158)')
plt.plot(method_label, rt_of_HiberniaGlobal,  color='orange', label='HiberniaGlobal(55)')
plt.plot(method_label, rt_of_Colt,  color='green', label='Colt(153)')
plt.plot(method_label, rt_of_Funet,  color='red', label='Funet(26)')
plt.plot(method_label, rt_of_Abvt,  color='purple', label='Abvt(23)')
plt.plot(method_label, rt_of_Intellifiber,  color='brown', label='Intellifiber(73)')
plt.plot(method_label, rt_of_TataNld,  color='pink', label='TataNld(145)')
plt.plot(method_label, rt_of_Internode,  color='olive', label='Internode(66)')
plt.plot(method_label, rt_of_Missouri,  color='cyan', label='Missouri(67)')
plt.plot(method_label, rt_of_Ion,  color='#FF5733', label='Ion(125)')
plt.plot(method_label, rt_of_Palmetto,  color='#33FF57', label='Palmetto(45)')

# Find the lowest running time for each topology
min_Cogent, i_Cogent = np.min(rt_of_Cogent), np.argmin(rt_of_Cogent)
min_UsCarrier, i_UsCarrier = np.min(rt_of_UsCarrier), np.argmin(rt_of_UsCarrier)
min_HiberniaGlobal, i_HiberniaGlobal = np.min(rt_of_HiberniaGlobal), np.argmin(rt_of_HiberniaGlobal)
min_Colt, i_Colt = np.min(rt_of_Colt), np.argmin(rt_of_Colt)
min_Funet, i_Funet = np.min(rt_of_Funet), np.argmin(rt_of_Funet)
min_Abvt, i_Abvt = np.min(rt_of_Abvt), np.argmin(rt_of_Abvt)
min_Intellifiber, i_Intellifiber = np.min(rt_of_Intellifiber), np.argmin(rt_of_Intellifiber)
min_TataNld, i_TataNld = np.min(rt_of_TataNld), np.argmin(rt_of_TataNld)
min_Internode, i_Internode = np.min(rt_of_Internode), np.argmin(rt_of_Internode)
min_Missouri, i_Missouri = np.min(rt_of_Missouri), np.argmin(rt_of_Missouri)
min_Ion, i_Ion = np.min(rt_of_Ion), np.argmin(rt_of_Ion)
min_Palmetto, i_Palmetto = np.min(rt_of_Palmetto), np.argmin(rt_of_Palmetto)

# scatter the lowest point
plt.scatter(i_Cogent, min_Cogent, color='black', marker="*", s=150)
plt.scatter(i_UsCarrier, min_UsCarrier, color='blue', marker="*", s=150)
plt.scatter(i_HiberniaGlobal, min_HiberniaGlobal, color='orange', marker="*", s=150)
plt.scatter(i_Colt, min_Colt, color='green', marker="*", s=150)
plt.scatter(i_Funet, min_Funet, color='red', marker="*", s=150)
plt.scatter(i_Abvt, min_Abvt, color='purple', marker="*", s=150)
plt.scatter(i_Intellifiber, min_Intellifiber, color='brown', marker="*", s=150)
plt.scatter(i_TataNld, min_TataNld, color='pink', marker="*", s=150)
plt.scatter(i_Internode, min_Internode, color='olive', marker="*", s=150)
plt.scatter(i_Missouri, min_Missouri, color='cyan', marker="*", s=150)
plt.scatter(i_Ion, min_Ion, color='#FF5733', marker="*", s=150)
plt.scatter(i_Palmetto, min_Palmetto, color='#33FF57', marker="*", s=150)

plt.title("Comparation of run time for each method")
plt.xlabel("Name of Methods")
plt.ylabel("Run Time (sec)")
plt.legend()
plt.show()

# %%
# Define and plot the x-axis (method name) and y-axis (running time)
plt.figure(figsize=(10, 5))
plt.plot(method_label, rt_of_Cogent,  color='black', label='Cogent(197)')
plt.plot(method_label, rt_of_UsCarrier,  color='blue', label='UsCarrier(158)')
plt.plot(method_label, rt_of_HiberniaGlobal,  color='orange', label='HiberniaGlobal(55)')
plt.plot(method_label, rt_of_Colt,  color='green', label='Colt(153)')
plt.plot(method_label, rt_of_Funet,  color='red', label='Funet(26)')
plt.plot(method_label, rt_of_Abvt,  color='purple', label='Abvt(23)')
plt.plot(method_label, rt_of_Intellifiber,  color='brown', label='Intellifiber(73)')
plt.plot(method_label, rt_of_TataNld,  color='pink', label='TataNld(145)')
plt.plot(method_label, rt_of_Internode,  color='olive', label='Internode(66)')
plt.plot(method_label, rt_of_Missouri,  color='cyan', label='Missouri(67)')
plt.plot(method_label, rt_of_Ion,  color='#FF5733', label='Ion(125)')
plt.plot(method_label, rt_of_Palmetto,  color='#33FF57', label='Palmetto(45)')

# scatter the lowest point
plt.scatter(i_Cogent, min_Cogent, color='black', marker="*", s=150)
plt.scatter(i_UsCarrier, min_UsCarrier, color='blue', marker="*", s=150)
plt.scatter(i_HiberniaGlobal, min_HiberniaGlobal, color='orange', marker="*", s=150)
plt.scatter(i_Colt, min_Colt, color='green', marker="*", s=150)
plt.scatter(i_Funet, min_Funet, color='red', marker="*", s=150)
plt.scatter(i_Abvt, min_Abvt, color='purple', marker="*", s=150)
plt.scatter(i_Intellifiber, min_Intellifiber, color='brown', marker="*", s=150)
plt.scatter(i_TataNld, min_TataNld, color='pink', marker="*", s=150)
plt.scatter(i_Internode, min_Internode, color='olive', marker="*", s=150)
plt.scatter(i_Missouri, min_Missouri, color='cyan', marker="*", s=150)
plt.scatter(i_Ion, min_Ion, color='#FF5733', marker="*", s=150)
plt.scatter(i_Palmetto, min_Palmetto, color='#33FF57', marker="*", s=150)

plt.title("Comparation of run time for each method")
plt.xlabel("Name of Methods")
plt.ylabel("Run Time (sec)")
plt.legend()
plt.show()

# %% [markdown]
# ## Store run time for all algorithms

# %%
rt_of_Cogent = [21221.9068279266000000,
21363.1395285129000000,
21842.3358607292000000,
22729.6911182403000000,
19845.1951382160000000,
19115.6564953327000000,
19394.2033953666000000,
22526.3356068134000000,
22391.9808471202000000,
20360.4141821861000000,
50951.7915918827000000,
50951.3842661380000000,
18380.6669692993000000,]
rt_of_UsCarrier = [676.8944079875940000,
687.0578308105460000,
661.3903326988220000,
662.2868342399590000,
660.4910416603080000,
577.2712814807890000,
641.0924780368800000,
756.2136864662170000,
639.3790032863610000,
577.6125988960260000,
1338.8145961761400000,
1352.1551654338800000,
590.9436695575710000,]
rt_of_HiberniaGlobal = [14925.3631951808000000,
16549.6134822368000000,
15851.9255151748000000,
16659.3571403026000000,
13692.5105969905000000,
13682.8467414379000000,
14705.9354286193000000,
17185.3371481895000000,
16426.2451949119000000,
13777.9448873996000000,
34231.0766654014000000,
33922.0406200885000000,
12853.8028938770000000,]
rt_of_Colt = [2011.0378723144500000,
2039.2775878906200000,
1993.5356299877100000,
1981.6246111392900000,
1956.1123681068400000,
1750.0828795433000000,
1934.3289566040000000,
2115.4214544296200000,


# %%
import matplotlib.pyplot as plt
import numpy as np

# Define and plot the x-axis (method name) and y-axis (running time)
plt.figure(figsize=(15, 5))
plt.plot(method_label, rt_of_Cogent,  color='black', label='Cogent(197)')
plt.plot(method_label, rt_of_UsCarrier,  color='blue', label='UsCarrier(158)')
plt.plot(method_label, rt_of_HiberniaGlobal,  color='orange', label='HiberniaGlobal(55)')
plt.plot(method_label, rt_of_Colt,  color='green', label='Colt(153)')
plt.plot(method_label, rt_of_Funet,  color='red', label='Funet(26)')
plt.plot(method_label, rt_of_Abvt,  color='purple', label='Abvt(23)')
plt.plot(method_label, rt_of_Intellifiber,  color='brown', label='Intellifiber(73)')
plt.plot(method_label, rt_of_TataNld,  color='pink', label='TataNld(145)')
plt.plot(method_label, rt_of_Internode,  color='olive', label='Internode(66)')
plt.plot(method_label, rt_of_Missouri,  color='cyan', label='Missouri(67)')
plt.plot(method_label, rt_of_Ion,  color='#FF5733', label='Ion(125)')
plt.plot(method_label, rt_of_Palmetto,  color='#33FF57', label='Palmetto(45)')

# Find the lowest running time for each topology
min_Cogent, i_Cogent = np.min(rt_of_Cogent), np.argmin(rt_of_Cogent)
min_UsCarrier, i_UsCarrier = np.min(rt_of_UsCarrier), np.argmin(rt_of_UsCarrier)
min_HiberniaGlobal, i_HiberniaGlobal = np.min(rt_of_HiberniaGlobal), np.argmin(rt_of_HiberniaGlobal)
min_Colt, i_Colt = np.min(rt_of_Colt), np.argmin(rt_of_Colt)
min_Funet, i_Funet = np.min(rt_of_Funet), np.argmin(rt_of_Funet)
min_Abvt, i_Abvt = np.min(rt_of_Abvt), np.argmin(rt_of_Abvt)
min_Intellifiber, i_Intellifiber = np.min(rt_of_Intellifiber), np.argmin(rt_of_Intellifiber)
min_TataNld, i_TataNld = np.min(rt_of_TataNld), np.argmin(rt_of_TataNld)
min_Internode, i_Internode = np.min(rt_of_Internode), np.argmin(rt_of_Internode)
min_Missouri, i_Missouri = np.min(rt_of_Missouri), np.argmin(rt_of_Missouri)
min_Ion, i_Ion = np.min(rt_of_Ion), np.argmin(rt_of_Ion)
min_Palmetto, i_Palmetto = np.min(rt_of_Palmetto), np.argmin(rt_of_Palmetto)

# scatter the lowest point
plt.scatter(i_Cogent, min_Cogent, color='black', marker="*", s=150)
plt.scatter(i_UsCarrier, min_UsCarrier, color='blue', marker="*", s=150)
plt.scatter(i_HiberniaGlobal, min_HiberniaGlobal, color='orange', marker="*", s=150)
plt.scatter(i_Colt, min_Colt, color='green', marker="*", s=150)
plt.scatter(i_Funet, min_Funet, color='red', marker="*", s=150)
plt.scatter(i_Abvt, min_Abvt, color='purple', marker="*", s=150)
plt.scatter(i_Intellifiber, min_Intellifiber, color='brown', marker="*", s=150)
plt.scatter(i_TataNld, min_TataNld, color='pink', marker="*", s=150)
plt.scatter(i_Internode, min_Internode, color='olive', marker="*", s=150)
plt.scatter(i_Missouri, min_Missouri, color='cyan', marker="*", s=150)
plt.scatter(i_Ion, min_Ion, color='#FF5733', marker="*", s=150)
plt.scatter(i_Palmetto, min_Palmetto, color='#33FF57', marker="*", s=150)

plt.title("Comparation of run time for each method")
plt.xlabel("Name of Methods")
plt.ylabel("Run Time (sec)")
plt.legend(loc='center left')
plt.show()
